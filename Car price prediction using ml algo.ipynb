# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo'

# %%
os.chdir ('Downloads')
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo\\Downloads'

# %%
df=pd.read_csv("audi.csv")
display(df)
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0        A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1        A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2        A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3        A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4        A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0
# ...     ...   ...    ...          ...      ...      ...  ...   ...         ...
# 10663    A3  2020  16999       Manual     4018   Petrol  145  49.6         1.0
# 10664    A3  2020  16999       Manual     1978   Petrol  150  49.6         1.0
# 10665    A3  2020  17199       Manual      609   Petrol  150  49.6         1.0
# 10666    Q3  2017  19499    Automatic     8646   Petrol  150  47.9         1.4
# 10667    Q3  2016  15999       Manual    11855   Petrol  150  47.9         1.4
#
# ...

# %%
display (df.dtypes )
# Out:
# model            object
# year              int64
# price             int64
# transmission     object
# mileage           int64
# fuelType         object
# tax               int64
# mpg             float64
# engineSize      float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10668 entries, 0 to 10667
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10668 non-null  object
#  1   year          10668 non-null  int64
#  2   price         10668 non-null  int64
#  3   transmission  10668 non-null  object
#  4   mileage       10668 non-null  int64
#  5   fuelType      10668 non-null  object
#  6   tax           10668 non-null  int64
#  7   mpg           10668 non-null  float64
#  8   engineSize    10668 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 750.2+ KB

# %%
df.describe ()
# Out:
#                year          price        mileage           tax           mpg  \
# count  10668.000000   10668.000000   10668.000000  10668.000000  10668.000000
# mean    2017.100675   22896.685039   24827.244001    126.011436     50.770022
# std        2.167494   11714.841888   23505.257205     67.170294     12.949782
# min     1997.000000    1490.000000       1.000000      0.000000     18.900000
# 25%     2016.000000   15130.750000    5968.750000    125.000000     40.900000
# 50%     2017.000000   20200.000000   19000.000000    145.000000     49.600000
# 75%     2019.000000   27990.000000   36464.500000    145.000000     58.900000
# max     2020.000000  145000.000000  323000.000000    580.000000    188.300000
#
#          engineSize
# count  10668.000000
# mean       1.930709
# std        0.602957
# min        0.000000
# 25%        1.500000
# 50%        2.000000
# 75%        2.000000
# max        6.300000

# %%
X = df.iloc[:,[0,1,3,4,5,6,7,8]].values
display (X)
# Out:
# array([[' A1', 2017, 'Manual', ..., 150, 55.4, 1.4],
#        [' A6', 2016, 'Automatic', ..., 20, 64.2, 2.0],
#        [' A1', 2016, 'Manual', ..., 30, 55.4, 1.4],
#        ...,
#        [' A3', 2020, 'Manual', ..., 150, 49.6, 1.0],
#        [' Q3', 2017, 'Automatic', ..., 150, 47.9, 1.4],
#        [' Q3', 2016, 'Manual', ..., 150, 47.9, 1.4]], dtype=object)

# %%
Y = df.iloc[:,[2]].values
display (Y)
# Out:
# array([[12500],
#        [16500],
#        [11000],
#        ...,
#        [17199],
#        [19499],
#        [15999]], dtype=int64)

# %%
from matplotlib import style
import  matplotlib.style
style.use ('ggplot')
x=df.iloc[:,[1]]
x1=df.iloc[:,[4]]
plt.plot (x,Y,'lime',label = 'Year',linewidth = 3)
plt.plot (x1,Y,'m',label='Mileage',linewidth=2)
plt.title ('First Graph')
plt.ylabel('actual price')
plt.legend()
plt.show()

# %%
display(pd.DataFrame(X).head(5))
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.583268  1.200728 -0.712333 -1.123544 -0.046450 -0.386836  1.050783
# 1  1.714479 -0.832828 -0.712333 -0.160831 -0.507834  0.483989 -0.954181
# 2 -0.583268  1.200728 -0.712333 -1.123544 -0.507834  0.217781  1.050783
# 3  1.714479 -0.832828 -0.712333 -0.545916 -0.046450  0.047853 -0.954181
# 4 -0.583268  1.200728 -0.712333 -0.738459  0.876318 -0.971285  1.050783
#
#           7         8         9
# 0  0.357147  0.357550 -0.880218
# 1 -1.578323  1.037130  0.114925
# 2 -1.429440  0.357550 -0.880218
# 3  0.282706  1.276528  0.114925
# 4  0.282706 -0.090355 -1.543647

# %%
from sklearn.preprocessing import LabelEncoder
le1 = LabelEncoder()
X[:,0] = le1.fit_transform(X[:,0])
le2 = LabelEncoder()
X[:,-4] = le2.fit_transform(X[:,-4])
display (X)
# Out:
# array([[ 0.        ,  1.2007284 , -0.71233307, ...,  0.35714729,
#          0.35755001, -0.88021837],
#        [ 1.        , -0.83282781, -0.71233307, ..., -1.57832278,
#          1.03713001,  0.11492465],
#        [ 0.        ,  1.2007284 , -0.71233307, ..., -1.42944047,
#          0.35755001, -0.88021837],
#        ...,
#        [ 0.        ,  1.2007284 , -0.71233307, ...,  0.35714729,
#         -0.09035499, -1.54364705],
#        [ 1.        , -0.83282781, -0.71233307, ...,  0.35714729,
#         -0.22163749, -0.88021837],
#        [ 0.        ,  1.2007284 , -0.71233307, ...,  0.35714729,
#         -0.22163749, -0.88021837]])

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
ct = ColumnTransformer(transformers = [('encoder',OneHotEncoder(),[2])],remainder='passthrough')
X = ct.fit_transform(X)
display (pd.DataFrame(X))
# Out:
#         0    1    2         3         4         5         6    7         8   \
# 0      1.0  0.0  0.0  1.200728 -1.123544 -0.046450 -0.386836  2.0  0.357147
# 1      1.0  0.0  1.0 -0.832828 -0.160831 -0.507834  0.483989  0.0 -1.578323
# 2      1.0  0.0  0.0  1.200728 -1.123544 -0.507834  0.217781  2.0 -1.429440
# 3      1.0  0.0  1.0 -0.832828 -0.545916 -0.046450  0.047853  0.0  0.282706
# 4      1.0  0.0  0.0  1.200728 -0.738459  0.876318 -0.971285  2.0  0.282706
# ...    ...  ...  ...       ...       ...       ...       ...  ...       ...
# 10663  1.0  0.0  0.0  1.200728 -0.738459  1.337702 -0.885343  2.0  0.282706
# 10664  1.0  0.0  0.0  1.200728 -0.738459  1.337702 -0.972136  2.0  0.357147
# 10665  1.0  0.0  0.0  1.200728 -0.738459  1.337702 -1.030381  2.0  0.357147
# 10666  1.0  0.0  1.0 -0.832828  0.609339 -0.046450 -0.688442  2.0  0.357147
# 10667  1.0  0.0  0.0  1.200728  0.609339 -0.507834 -0.551913  2.0  0.357147
#
#              9         10
# 0      0.357550 -0.880218
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)
display (pd.DataFrame(X))
# Out:
#              0         1         2         3         4         5         6   \
# 0      0.712333 -0.712333 -0.583268  1.200728 -1.123544 -0.046450 -0.386836
# 1      0.712333 -0.712333  1.714479 -0.832828 -0.160831 -0.507834  0.483989
# 2      0.712333 -0.712333 -0.583268  1.200728 -1.123544 -0.507834  0.217781
# 3      0.712333 -0.712333  1.714479 -0.832828 -0.545916 -0.046450  0.047853
# 4      0.712333 -0.712333 -0.583268  1.200728 -0.738459  0.876318 -0.971285
# ...         ...       ...       ...       ...       ...       ...       ...
# 10663  0.712333 -0.712333 -0.583268  1.200728 -0.738459  1.337702 -0.885343
# 10664  0.712333 -0.712333 -0.583268  1.200728 -0.738459  1.337702 -0.972136
# 10665  0.712333 -0.712333 -0.583268  1.200728 -0.738459  1.337702 -1.030381
# 10666  0.712333 -0.712333  1.714479 -0.832828  0.609339 -0.046450 -0.688442
# 10667  0.712333 -0.712333 -0.583268  1.200728  0.609339 -0.507834 -0.551913
#
#              7         8         9         10
# ...

# %%
from sklearn.model_selection import train_test_split
(X_train,X_test,Y_train,Y_test) = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor
regression = RandomForestRegressor(random_state=0)
regression.fit(X_train,Y_train)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp/ipykernel_2288/1870461991.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regression.fit(X_train,Y_train)
# RandomForestRegressor(random_state=0)

# %%
y_pred = regression.predict(X_test)
display (y_pred)
# Out:
# array([14274.37, 23493.8 , 27351.24, ..., 46322.12, 31282.2 ,  9942.21])

# %%
print(np.concatenate((y_pred.reshape(len(y_pred),1),Y_test.reshape(len(Y_test),1)),1))
# Out:
# [[14274.37 14998.  ]
#  [23493.8  21950.  ]
#  [27351.24 28990.  ]
#  ...
#  [46322.12 45995.  ]
#  [31282.2  30500.  ]
#  [ 9942.21  8400.  ]]

# %%
from sklearn.metrics import r2_score,mean_absolute_error
print  ('R2 Score ', r2_score(Y_test, y_pred))
print  ('Mean Absolute Error', mean_absolute_error(Y_test,y_pred))
# Out:
# R2 Score  0.952853902119688
# Mean Absolute Error 1543.1525118511943

# %%
y_pred = regression.predict(X_test)
display (y_pred)
# Out:
# array([14274.37, 23493.8 , 27351.24, ..., 46322.12, 31282.2 ,  9942.21])

# %%
print(np.concatenate((y_pred.reshape(len(y_pred),1),Y_test.reshape(len(Y_test),1)),1))
# Out:
# [[14274.37 14998.  ]
#  [23493.8  21950.  ]
#  [27351.24 28990.  ]
#  ...
#  [46322.12 45995.  ]
#  [31282.2  30500.  ]
#  [ 9942.21  8400.  ]]

# %%
from sklearn.metrics import r2_score,mean_absolute_error
print  ('R2 Score ', r2_score(Y_test, y_pred))
print  ('Mean Absolute Error', mean_absolute_error(Y_test,y_pred))
# Out:
# R2 Score  0.952853902119688
# Mean Absolute Error 1543.1525118511943

# %%
y_pred = regression.predict(X)
display (y_pred)
# Out:
# array([12866.75, 16435.66, 11755.03, ..., 17657.78, 20240.88, 18413.32])

# %%
from matplotlib import style
import  matplotlib.style
style.use ('ggplot')
x=df.iloc[:,[1]]
x1=df.iloc[:,[4]]
plt.plot (x,y_pred,'lime',label = 'Year',linewidth = 3)
plt.plot (x1,y_pred,'y',label='Mileage',linewidth=2)
plt.title ('Latest Graph')
plt.ylabel('actual price')
plt.legend()
plt.show()

# %%
result = pd.concat([df,pd.DataFrame(y_pred)],axis=1)
display( result)
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        A1  2017  12500       Manual    15735   Petrol  150  55.4
# 1        A6  2016  16500    Automatic    36203   Diesel   20  64.2
# 2        A1  2016  11000       Manual    29946   Petrol   30  55.4
# 3        A4  2017  16800    Automatic    25952   Diesel  145  67.3
# 4        A3  2019  17300       Manual     1998   Petrol  145  49.6
# ...     ...   ...    ...          ...      ...      ...  ...   ...
# 10663    A3  2020  16999       Manual     4018   Petrol  145  49.6
# 10664    A3  2020  16999       Manual     1978   Petrol  150  49.6
# 10665    A3  2020  17199       Manual      609   Petrol  150  49.6
# 10666    Q3  2017  19499    Automatic     8646   Petrol  150  47.9
# 10667    Q3  2016  15999       Manual    11855   Petrol  150  47.9
#
#        engineSize         0
# 0             1.4  12866.75
# 1             2.0  16435.66
# 2             1.4  11755.03
# 3             2.0  17675.87
# ...

# %%
result.to_excel('output.xlsx')
result
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        A1  2017  12500       Manual    15735   Petrol  150  55.4
# 1        A6  2016  16500    Automatic    36203   Diesel   20  64.2
# 2        A1  2016  11000       Manual    29946   Petrol   30  55.4
# 3        A4  2017  16800    Automatic    25952   Diesel  145  67.3
# 4        A3  2019  17300       Manual     1998   Petrol  145  49.6
# ...     ...   ...    ...          ...      ...      ...  ...   ...
# 10663    A3  2020  16999       Manual     4018   Petrol  145  49.6
# 10664    A3  2020  16999       Manual     1978   Petrol  150  49.6
# 10665    A3  2020  17199       Manual      609   Petrol  150  49.6
# 10666    Q3  2017  19499    Automatic     8646   Petrol  150  47.9
# 10667    Q3  2016  15999       Manual    11855   Petrol  150  47.9
#
#        engineSize         0
# 0             1.4  12864.85
# 1             2.0  16457.12
# 2             1.4  11755.03
# 3             2.0  17664.67
# ...
